# %%
print ("Hello")
# Out:
# Hello

# %%
print(3)
# Out:
# 3

# %%
print (3)
print ("more string")
# Out:
# 3
# more string

# %%
a=1

# %%
print (a)
# Out:
# 1

# %%
b = 2

# %%
print (b)
# Out:
# 2

# %%
print (a)
print (b)
# Out:
# 1
# 2

# %%
c = ("hello there")

# %%
print (c)
# Out:
# hello there

# %%
print (b)
# Out:
# 2
